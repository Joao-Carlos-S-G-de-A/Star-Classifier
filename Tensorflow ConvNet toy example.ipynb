# %% [markdown]
# # Toy Example

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import cifar10 as cf10
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.13.1

# %%
(train_images, train_labels), (test_images, test_labels) = cf10.load_data()

# %%
import matplotlib.pyplot as plt

def show_images(train_images, class_names, train_labels, nb_samples=12, nb_row=4):
    plt.figure(figsize=(12, 12))
    for i in range(nb_samples):
        plt.subplot(nb_row, nb_row, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(train_images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[train_labels[i][0]])
    plt.show()

# %% [markdown]
# ### Print data to check it is ok

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           	'dog', 'frog', 'horse', 'ship', 'truck']

show_images(train_images, class_names, train_labels)

# %% [markdown]
# ### Normalize data

# %%
max_pixel_value = 255

train_images = train_images / max_pixel_value
test_images = test_images / max_pixel_value

# %% [markdown]
# ### Make labels numerical

# %%
from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels, len(class_names))
test_labels = to_categorical(test_labels, len(class_names))

# %% [markdown]
# ### Define Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Variables
INPUT_SHAPE = (32, 32, 3)
FILTER1_SIZE = 32
FILTER2_SIZE = 64
FILTER_SHAPE = (3, 3)
POOL_SHAPE = (2, 2)
FULLY_CONNECT_NUM = 128
NUM_CLASSES = len(class_names)

# Model architecture implementation
model = Sequential()
model.add(Conv2D(FILTER1_SIZE, FILTER_SHAPE, activation='relu', input_shape=INPUT_SHAPE))
model.add(MaxPooling2D(POOL_SHAPE))
model.add(Conv2D(FILTER2_SIZE, FILTER_SHAPE, activation='relu'))
model.add(MaxPooling2D(POOL_SHAPE))
model.add(Flatten())
model.add(Dense(FULLY_CONNECT_NUM, activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

# %% [markdown]
# ### Train Model

# %%
from tensorflow.keras.metrics import Precision, Recall

BATCH_SIZE = 32
EPOCHS = 30

METRICS = metrics=['accuracy',
               	Precision(name='precision'),
               	Recall(name='recall')]

model.compile(optimizer='adam',
          	loss='categorical_crossentropy',
          	metrics = METRICS)

# Train the model
training_history = model.fit(train_images, train_labels,
                	epochs=EPOCHS, batch_size=BATCH_SIZE,
                	validation_data=(test_images, test_labels))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 25s 15ms/step - loss: 1.4262 - accuracy: 0.4909 - precision: 0.7139 - recall: 0.2692 - val_loss: 1.1334 - val_accuracy: 0.6128 - val_precision: 0.7817 - val_recall: 0.4153
# Epoch 2/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.0628 - accuracy: 0.6279 - precision: 0.7658 - recall: 0.4830 - val_loss: 1.0168 - val_accuracy: 0.6442 - val_precision: 0.7737 - val_recall: 0.5084
# Epoch 3/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.9233 - accuracy: 0.6788 - precision: 0.7917 - recall: 0.5641 - val_loss: 0.9794 - val_accuracy: 0.6625 - val_precision: 0.7664 - val_recall: 0.5612
# Epoch 4/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.8276 - accuracy: 0.7139 - precision: 0.8133 - recall: 0.6186 - val_loss: 0.9191 - val_accuracy: 0.6875 - val_precision: 0.7739 - val_recall: 0.6071
# Epoch 5/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.7447 - accuracy: 0.7420 - precision: 0.8287 - recall: 0.6599 - val_loss: 0.9010 - val_accuracy: 0.6942 - val_precision: 0.7745 - val_recall: 0.6204
# Epoch 6/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.6730 - accuracy: 0.7659 - precision: 0.8405 - recall: 0.6966 - val_loss: 0.9027 - val_accuracy: 0.6975 - val_precision: 0.7685 - val_recall: 0.6302
# Epoch 7/30
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.6033 - accuracy: 0.7896 - precision: 0.8539 - recall: 0.7303 - val_loss: 0.9248 - val_accuracy: 0.6977 - val_precision: 0.7597 - val_recall: 0.6428
# Epoch 8/30
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.5440 - accuracy: 0.8107 - precision: 0.8642 - recall: 0.7602 - val_loss: 0.9410 - val_accuracy: 0.6946 - val_precision: 0.7470 - val_recall: 0.6453
# Epoch 9/30
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.4849 - accuracy: 0.8313 - precision: 0.8788 - recall: 0.7876 - val_loss: 0.9439 - val_accuracy: 0.7096 - val_precision: 0.7565 - val_recall: 0.6657
# Epoch 10/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.4327 - accuracy: 0.8464 - precision: 0.8870 - recall: 0.8094 - val_loss: 1.0007 - val_accuracy: 0.6959 - val_precision: 0.7446 - val_recall: 0.6570
# Epoch 11/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.3808 - accuracy: 0.8663 - precision: 0.8988 - recall: 0.8361 - val_loss: 1.0690 - val_accuracy: 0.6959 - val_precision: 0.7292 - val_recall: 0.6687
# Epoch 12/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.3382 - accuracy: 0.8809 - precision: 0.9079 - recall: 0.8548 - val_loss: 1.1244 - val_accuracy: 0.6901 - val_precision: 0.7237 - val_recall: 0.6645
# Epoch 13/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.2941 - accuracy: 0.8968 - precision: 0.9182 - recall: 0.8759 - val_loss: 1.2303 - val_accuracy: 0.6893 - val_precision: 0.7174 - val_recall: 0.6683
# Epoch 14/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.2563 - accuracy: 0.9097 - precision: 0.9280 - recall: 0.8934 - val_loss: 1.3181 - val_accuracy: 0.6887 - val_precision: 0.7092 - val_recall: 0.6721
# Epoch 15/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.2227 - accuracy: 0.9217 - precision: 0.9361 - recall: 0.9083 - val_loss: 1.4105 - val_accuracy: 0.6907 - val_precision: 0.7089 - val_recall: 0.6752
# Epoch 16/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1949 - accuracy: 0.9312 - precision: 0.9439 - recall: 0.9201 - val_loss: 1.4995 - val_accuracy: 0.6820 - val_precision: 0.6984 - val_recall: 0.6690
# Epoch 17/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1785 - accuracy: 0.9373 - precision: 0.9476 - recall: 0.9285 - val_loss: 1.5751 - val_accuracy: 0.6800 - val_precision: 0.6961 - val_recall: 0.6673
# Epoch 18/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1539 - accuracy: 0.9455 - precision: 0.9531 - recall: 0.9384 - val_loss: 1.8131 - val_accuracy: 0.6860 - val_precision: 0.6976 - val_recall: 0.6774
# Epoch 19/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1433 - accuracy: 0.9492 - precision: 0.9557 - recall: 0.9431 - val_loss: 1.7676 - val_accuracy: 0.6848 - val_precision: 0.6973 - val_recall: 0.6770
# Epoch 20/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1276 - accuracy: 0.9542 - precision: 0.9597 - recall: 0.9491 - val_loss: 1.8621 - val_accuracy: 0.6857 - val_precision: 0.6974 - val_recall: 0.6784
# Epoch 21/30
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1221 - accuracy: 0.9566 - precision: 0.9618 - recall: 0.9522 - val_loss: 1.9932 - val_accuracy: 0.6790 - val_precision: 0.6866 - val_recall: 0.6696
# Epoch 22/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1130 - accuracy: 0.9594 - precision: 0.9639 - recall: 0.9556 - val_loss: 2.0571 - val_accuracy: 0.6795 - val_precision: 0.6899 - val_recall: 0.6752
# Epoch 23/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1090 - accuracy: 0.9625 - precision: 0.9660 - recall: 0.9594 - val_loss: 2.1023 - val_accuracy: 0.6744 - val_precision: 0.6846 - val_recall: 0.6677
# Epoch 24/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0982 - accuracy: 0.9657 - precision: 0.9691 - recall: 0.9626 - val_loss: 2.1949 - val_accuracy: 0.6783 - val_precision: 0.6860 - val_recall: 0.6713
# Epoch 25/30
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0983 - accuracy: 0.9656 - precision: 0.9687 - recall: 0.9629 - val_loss: 2.2948 - val_accuracy: 0.6707 - val_precision: 0.6787 - val_recall: 0.6649
# Epoch 26/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0912 - accuracy: 0.9676 - precision: 0.9702 - recall: 0.9654 - val_loss: 2.6847 - val_accuracy: 0.6632 - val_precision: 0.6683 - val_recall: 0.6587
# Epoch 27/30
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.0912 - accuracy: 0.9682 - precision: 0.9709 - recall: 0.9660 - val_loss: 2.5027 - val_accuracy: 0.6697 - val_precision: 0.6767 - val_recall: 0.6640
# Epoch 28/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0848 - accuracy: 0.9698 - precision: 0.9720 - recall: 0.9681 - val_loss: 2.5127 - val_accuracy: 0.6752 - val_precision: 0.6805 - val_recall: 0.6708
# Epoch 29/30
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0851 - accuracy: 0.9713 - precision: 0.9729 - recall: 0.9697 - val_loss: 2.6540 - val_accuracy: 0.6719 - val_precision: 0.6787 - val_recall: 0.6676
# Epoch 30/30
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0845 - accuracy: 0.9712 - precision: 0.9728 - recall: 0.9698 - val_loss: 2.7201 - val_accuracy: 0.6709 - val_precision: 0.6754 - val_recall: 0.6668

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# ### Performance curve

# %%
def show_performance_curve(training_result, metric, metric_label):
    
	train_perf = training_result.history[str(metric)]
	validation_perf = training_result.history['val_'+str(metric)]
	intersection_idx = np.argwhere(np.isclose(train_perf,
                                            	validation_perf, atol=1e-2)).flatten()[0]
	intersection_value = train_perf[intersection_idx]
    
	plt.plot(train_perf, label=metric_label)
	plt.plot(validation_perf, label = 'val_'+str(metric))
	plt.axvline(x=intersection_idx, color='r', linestyle='--', label='Intersection')
    
	plt.annotate(f'Optimal Value: {intersection_value:.4f}',
         	xy=(intersection_idx, intersection_value),
         	xycoords='data',
         	fontsize=10,
         	color='green')
            	 
	plt.xlabel('Epoch')
	plt.ylabel(metric_label)
	plt.legend(loc='lower right')

# %%
show_performance_curve(training_history, 'accuracy', 'accuracy')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 show_performance_curve(training_history, 'accuracy', 'accuracy')
#
# Cell In[16], line 5, in show_performance_curve(training_result, metric, metric_label)
#       3 	train_perf = training_result.history[str(metric)]
#       4 	validation_perf = training_result.history['val_'+str(metric)]
# ----> 5 	intersection_idx = np.argwhere(np.isclose(train_perf,
#       6                                             	validation_perf, atol=1e-2)).flatten()[0]
#       7 	intersection_value = train_perf[intersection_idx]
#       9 	plt.plot(train_perf, label=metric_label)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
show_performance_curve(training_history, 'precision', 'precision')

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test_predictions = model.predict(test_images)

test_predicted_labels = np.argmax(test_predictions, axis=1)

test_true_labels = np.argmax(test_labels, axis=1)

cm = confusion_matrix(test_true_labels, test_predicted_labels)

cmd = ConfusionMatrixDisplay(confusion_matrix=cm)

cmd.plot(include_values=True, cmap='viridis', ax=None, xticks_rotation='horizontal')
plt.show()
# Out:
# 313/313 [==============================] - 1s 4ms/step
